# %% [markdown]
# <a href="https://colab.research.google.com/github/mdaugherity/MachineLearning2023/blob/main/data/Class_Challenge_03_20_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dr. Daugherity, PHYS 453, Spring 2023**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets

# %%
df_sample = pd.DataFrame(X_train)
df_sample.describe()
# Out:
#                0           1           2           3           4           5   \
# count  168.000000  168.000000  168.000000  168.000000  168.000000  168.000000
# mean    12.991429    2.321905    2.361131   19.469643   99.761905    2.295179
# std      0.807605    1.121977    0.273245    3.399996   14.373228    0.629464
# min     11.030000    0.740000    1.360000   10.600000   70.000000    0.980000
# 25%     12.355000    1.607500    2.210000   17.075000   88.000000    1.735000
# 50%     13.050000    1.830000    2.360000   19.250000   98.000000    2.355000
# 75%     13.672500    3.030000    2.540000   21.500000  107.000000    2.800000
# max     14.830000    5.800000    3.230000   30.000000  162.000000    3.880000
#
#                6           7           8           9           10          11  \
# count  168.000000  168.000000  168.000000  168.000000  168.000000  168.000000
# mean     2.028750    0.363452    1.593571    5.071369    0.959262    2.599405
# ...

# %%
df_sample.to_csv('data03202023.csv')

# %%
df_target = pd.DataFrame(y_train)
df_target.to_csv('target03202023.csv')

# %%
df_pred = pd.DataFrame(X_test)
df_pred.to_csv('pred03202023.csv')
